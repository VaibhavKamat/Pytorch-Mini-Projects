# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Loading the diabetes classification dataset
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure  Triceps skin fold thickness  \
# 0                        72                           35
# 1                        66                           29
# 2                        64                            0
# 3                        66                           23
# 4                        40                           35
#
#    2-Hour serum insulin  Body mass index  Age     Class
# 0                     0             33.6   50  positive
# 1                     0             26.6   31  negative
# 2                     0             23.3   32  positive
# 3                    94             28.1   21  negative
# 4                   168             43.1   33  positive

# %%
# Feature Extraction and Processing

# Function to convert label to 1s and 0s
def convert_label(label):
    if label == 'positive':
        return 1
    else:
        return 0


X = data.iloc[:,:-1].values
sc = StandardScaler()
X = sc.fit_transform(X)
X = torch.tensor(X)


y_string= list(data.iloc[:,-1])
y_int = []

# Coverting the labels to 0s and 1s
for string in y_string:
    if string == 'positive':
        y_int.append(1)
    else:
        y_int.append(0)

Y = np.array(y_int, dtype = 'float64')   
#Y = data.iloc[:,-1].apply(convert_label).values.astype('float64')
Y = torch.tensor(Y).unsqueeze(1)

#print(X)
#print(Y)

# %%
class Dataset(Dataset):
    def __init__(self, x, y):
        self.X = x
        self.Y = y
        
    def __getitem__(self, index):
        return self.X[index], self.Y[index]
    
    def __len__(self):
        return len(self.X)
    
class Model(nn.Module):
    def __init__(self, input_features, output_features=1):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(input_features, 5)
        self.fc2 = nn.Linear(5, 4)
        self.fc3 = nn.Linear(4, 3)
        self.fc4 = nn.Linear(3, output_features)
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()

    def forward(self, x):
        out = self.fc1(x)
        out = self.tanh(out)
        out = self.fc2(out)
        out = self.tanh(out)
        out = self.fc3(out)
        out = self.tanh(out)
        out = self.fc4(out)
        out = self.sigmoid(out)
        return out

# %%
# Load the data using DataLoader for batch processing and shuffling
dataset = Dataset(X, Y)
train_loader = DataLoader(dataset=dataset, batch_size=32, shuffle=True)

print("There are {} batches in the dataset:".format(len(train_loader)))
for (x,y) in train_loader:
    print("For one iteration, there are:")
    print("Data: {}".format(x.shape))
    print("labels: {}".format(y.shape))
    break
# Out:
# There are 24 batches in the dataset:
# For one iteration, there are:
# Data: torch.Size([32, 7])
# labels: torch.Size([32, 1])

# %%
model = Model(X.shape[1], 1)

# Define the loss function and the optimizer
criterion = torch.nn.BCELoss(reduction='mean')
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.8)

# %%
# Train the network

epochs = 200

for epoch in range(epochs):
    for inputs, labels in train_loader:
        inputs = inputs.float()
        labels = labels.float()
        
        # Forward propagation
        output = model(inputs) # or can do model.forward()
        loss = criterion(output, labels) # Loss Calculation
        optimizer.zero_grad # Clear the Gradient Buffer
        
        loss.backward() # performing backpropagation and calculating the gradients
        optimizer.step() # Updating the weights
    
    # Accuracy Calculation
    output = (output>0.5).float()
    accuracy = (output == labels).float().mean()
    print("Epoch {}/{}, Loss = {:.3f}, Accuracy = {:.3f}".format(epoch+1,epochs,loss,accuracy))
# Out:
# Epoch 1/200, Loss = 1.548, Accuracy = 0.625
# Epoch 2/200, Loss = 19.481, Accuracy = 0.781
# Epoch 3/200, Loss = 30.486, Accuracy = 0.344
# Epoch 4/200, Loss = 40.625, Accuracy = 0.594
# Epoch 5/200, Loss = 25.000, Accuracy = 0.750
# Epoch 6/200, Loss = 37.500, Accuracy = 0.625
# Epoch 7/200, Loss = 15.625, Accuracy = 0.844
# Epoch 8/200, Loss = 18.750, Accuracy = 0.812
# Epoch 9/200, Loss = 18.750, Accuracy = 0.812
# Epoch 10/200, Loss = 18.750, Accuracy = 0.812
# Epoch 11/200, Loss = 25.000, Accuracy = 0.750
# Epoch 12/200, Loss = 25.000, Accuracy = 0.750
# Epoch 13/200, Loss = 31.250, Accuracy = 0.688
# Epoch 14/200, Loss = 28.125, Accuracy = 0.719
# Epoch 15/200, Loss = 40.625, Accuracy = 0.594
# Epoch 16/200, Loss = 25.000, Accuracy = 0.750
# Epoch 17/200, Loss = 18.750, Accuracy = 0.812
# Epoch 18/200, Loss = 34.375, Accuracy = 0.656
# Epoch 19/200, Loss = 37.500, Accuracy = 0.625
# Epoch 20/200, Loss = 40.625, Accuracy = 0.594
# Epoch 21/200, Loss = 25.000, Accuracy = 0.750
# Epoch 22/200, Loss = 25.000, Accuracy = 0.750
# Epoch 23/200, Loss = 34.375, Accuracy = 0.656
# Epoch 24/200, Loss = 37.500, Accuracy = 0.625
# Epoch 25/200, Loss = 37.500, Accuracy = 0.625
# Epoch 26/200, Loss = 40.625, Accuracy = 0.594
# Epoch 27/200, Loss = 43.750, Accuracy = 0.562
# Epoch 28/200, Loss = 31.250, Accuracy = 0.688
# Epoch 29/200, Loss = 25.000, Accuracy = 0.750
# Epoch 30/200, Loss = 34.375, Accuracy = 0.656
# Epoch 31/200, Loss = 43.750, Accuracy = 0.562
# Epoch 32/200, Loss = 31.250, Accuracy = 0.688
# Epoch 33/200, Loss = 34.375, Accuracy = 0.656
# Epoch 34/200, Loss = 28.125, Accuracy = 0.719
# Epoch 35/200, Loss = 28.125, Accuracy = 0.719
# Epoch 36/200, Loss = 37.500, Accuracy = 0.625
# Epoch 37/200, Loss = 28.125, Accuracy = 0.719
# Epoch 38/200, Loss = 25.000, Accuracy = 0.750
# Epoch 39/200, Loss = 25.000, Accuracy = 0.750
# Epoch 40/200, Loss = 31.250, Accuracy = 0.688
# Epoch 41/200, Loss = 37.500, Accuracy = 0.625
# Epoch 42/200, Loss = 21.875, Accuracy = 0.781
# Epoch 43/200, Loss = 40.625, Accuracy = 0.594
# Epoch 44/200, Loss = 28.125, Accuracy = 0.719
# Epoch 45/200, Loss = 25.000, Accuracy = 0.750
# Epoch 46/200, Loss = 37.500, Accuracy = 0.625
# Epoch 47/200, Loss = 37.500, Accuracy = 0.625
# Epoch 48/200, Loss = 37.500, Accuracy = 0.625
# Epoch 49/200, Loss = 31.250, Accuracy = 0.688
# Epoch 50/200, Loss = 34.375, Accuracy = 0.656
# Epoch 51/200, Loss = 18.750, Accuracy = 0.812
# Epoch 52/200, Loss = 18.750, Accuracy = 0.812
# Epoch 53/200, Loss = 21.875, Accuracy = 0.781
# Epoch 54/200, Loss = 28.125, Accuracy = 0.719
# Epoch 55/200, Loss = 21.875, Accuracy = 0.781
# Epoch 56/200, Loss = 21.875, Accuracy = 0.781
# Epoch 57/200, Loss = 25.000, Accuracy = 0.750
# Epoch 58/200, Loss = 21.875, Accuracy = 0.781
# Epoch 59/200, Loss = 31.250, Accuracy = 0.688
# Epoch 60/200, Loss = 28.125, Accuracy = 0.719
# Epoch 61/200, Loss = 37.500, Accuracy = 0.625
# Epoch 62/200, Loss = 40.625, Accuracy = 0.594
# Epoch 63/200, Loss = 25.000, Accuracy = 0.750
# Epoch 64/200, Loss = 21.875, Accuracy = 0.781
# Epoch 65/200, Loss = 28.125, Accuracy = 0.719
# Epoch 66/200, Loss = 28.125, Accuracy = 0.719
# Epoch 67/200, Loss = 34.375, Accuracy = 0.656
# Epoch 68/200, Loss = 50.000, Accuracy = 0.500
# Epoch 69/200, Loss = 28.125, Accuracy = 0.719
# Epoch 70/200, Loss = 18.750, Accuracy = 0.812
# Epoch 71/200, Loss = 28.125, Accuracy = 0.719
# Epoch 72/200, Loss = 28.125, Accuracy = 0.719
# Epoch 73/200, Loss = 46.875, Accuracy = 0.531
# Epoch 74/200, Loss = 15.625, Accuracy = 0.844
# Epoch 75/200, Loss = 28.125, Accuracy = 0.719
# Epoch 76/200, Loss = 12.500, Accuracy = 0.875
# Epoch 77/200, Loss = 18.750, Accuracy = 0.812
# Epoch 78/200, Loss = 28.125, Accuracy = 0.719
# Epoch 79/200, Loss = 37.500, Accuracy = 0.625
# Epoch 80/200, Loss = 18.750, Accuracy = 0.812
# Epoch 81/200, Loss = 28.125, Accuracy = 0.719
# Epoch 82/200, Loss = 37.500, Accuracy = 0.625
# Epoch 83/200, Loss = 25.000, Accuracy = 0.750
# Epoch 84/200, Loss = 40.625, Accuracy = 0.594
# Epoch 85/200, Loss = 25.000, Accuracy = 0.750
# Epoch 86/200, Loss = 40.625, Accuracy = 0.594
# Epoch 87/200, Loss = 28.125, Accuracy = 0.719
# Epoch 88/200, Loss = 18.750, Accuracy = 0.812
# Epoch 89/200, Loss = 28.125, Accuracy = 0.719
# Epoch 90/200, Loss = 40.625, Accuracy = 0.594
# Epoch 91/200, Loss = 28.125, Accuracy = 0.719
# Epoch 92/200, Loss = 40.625, Accuracy = 0.594
# Epoch 93/200, Loss = 12.500, Accuracy = 0.875
# Epoch 94/200, Loss = 18.750, Accuracy = 0.812
# Epoch 95/200, Loss = 34.375, Accuracy = 0.656
# Epoch 96/200, Loss = 21.875, Accuracy = 0.781
# Epoch 97/200, Loss = 34.375, Accuracy = 0.656
# Epoch 98/200, Loss = 28.125, Accuracy = 0.719
# Epoch 99/200, Loss = 37.500, Accuracy = 0.625
# Epoch 100/200, Loss = 28.125, Accuracy = 0.719
# Epoch 101/200, Loss = 34.375, Accuracy = 0.656
# Epoch 102/200, Loss = 31.250, Accuracy = 0.688
# Epoch 103/200, Loss = 31.250, Accuracy = 0.688
# Epoch 104/200, Loss = 12.500, Accuracy = 0.875
# Epoch 105/200, Loss = 37.500, Accuracy = 0.625
# Epoch 106/200, Loss = 34.375, Accuracy = 0.656
# Epoch 107/200, Loss = 37.500, Accuracy = 0.625
# Epoch 108/200, Loss = 25.000, Accuracy = 0.750
# Epoch 109/200, Loss = 21.875, Accuracy = 0.781
# Epoch 110/200, Loss = 18.750, Accuracy = 0.812
# Epoch 111/200, Loss = 46.875, Accuracy = 0.531
# Epoch 112/200, Loss = 21.875, Accuracy = 0.781
# Epoch 113/200, Loss = 28.125, Accuracy = 0.719
# Epoch 114/200, Loss = 28.125, Accuracy = 0.719
# Epoch 115/200, Loss = 25.000, Accuracy = 0.750
# Epoch 116/200, Loss = 37.500, Accuracy = 0.625
# Epoch 117/200, Loss = 15.625, Accuracy = 0.844
# Epoch 118/200, Loss = 31.250, Accuracy = 0.688
# Epoch 119/200, Loss = 21.875, Accuracy = 0.781
# Epoch 120/200, Loss = 18.750, Accuracy = 0.812
# Epoch 121/200, Loss = 25.000, Accuracy = 0.750
# Epoch 122/200, Loss = 34.375, Accuracy = 0.656
# Epoch 123/200, Loss = 34.375, Accuracy = 0.656
# Epoch 124/200, Loss = 15.625, Accuracy = 0.844
# Epoch 125/200, Loss = 25.000, Accuracy = 0.750
# Epoch 126/200, Loss = 18.750, Accuracy = 0.812
# Epoch 127/200, Loss = 28.125, Accuracy = 0.719
# Epoch 128/200, Loss = 37.500, Accuracy = 0.625
# Epoch 129/200, Loss = 28.125, Accuracy = 0.719
# Epoch 130/200, Loss = 25.000, Accuracy = 0.750
# Epoch 131/200, Loss = 40.625, Accuracy = 0.594
# Epoch 132/200, Loss = 25.000, Accuracy = 0.750
# Epoch 133/200, Loss = 31.250, Accuracy = 0.688
# Epoch 134/200, Loss = 21.875, Accuracy = 0.781
# Epoch 135/200, Loss = 18.750, Accuracy = 0.812
# Epoch 136/200, Loss = 25.000, Accuracy = 0.750
# Epoch 137/200, Loss = 34.375, Accuracy = 0.656
# Epoch 138/200, Loss = 18.750, Accuracy = 0.812
# Epoch 139/200, Loss = 34.375, Accuracy = 0.656
# Epoch 140/200, Loss = 37.500, Accuracy = 0.625
# Epoch 141/200, Loss = 46.875, Accuracy = 0.531
# Epoch 142/200, Loss = 21.875, Accuracy = 0.781
# Epoch 143/200, Loss = 40.625, Accuracy = 0.594
# Epoch 144/200, Loss = 40.625, Accuracy = 0.594
# Epoch 145/200, Loss = 34.375, Accuracy = 0.656
# Epoch 146/200, Loss = 28.125, Accuracy = 0.719
# Epoch 147/200, Loss = 34.375, Accuracy = 0.656
# Epoch 148/200, Loss = 37.500, Accuracy = 0.625
# Epoch 149/200, Loss = 31.250, Accuracy = 0.688
# Epoch 150/200, Loss = 15.625, Accuracy = 0.844
# Epoch 151/200, Loss = 6.250, Accuracy = 0.938
# Epoch 152/200, Loss = 25.000, Accuracy = 0.750
# Epoch 153/200, Loss = 40.625, Accuracy = 0.594
# Epoch 154/200, Loss = 40.625, Accuracy = 0.594
# Epoch 155/200, Loss = 34.375, Accuracy = 0.656
# Epoch 156/200, Loss = 21.875, Accuracy = 0.781
# Epoch 157/200, Loss = 25.000, Accuracy = 0.750
# Epoch 158/200, Loss = 21.875, Accuracy = 0.781
# Epoch 159/200, Loss = 34.375, Accuracy = 0.656
# Epoch 160/200, Loss = 40.625, Accuracy = 0.594
# Epoch 161/200, Loss = 31.250, Accuracy = 0.688
# Epoch 162/200, Loss = 25.000, Accuracy = 0.750
# Epoch 163/200, Loss = 25.000, Accuracy = 0.750
# Epoch 164/200, Loss = 37.500, Accuracy = 0.625
# Epoch 165/200, Loss = 28.125, Accuracy = 0.719
# Epoch 166/200, Loss = 28.125, Accuracy = 0.719
# Epoch 167/200, Loss = 12.500, Accuracy = 0.875
# Epoch 168/200, Loss = 28.125, Accuracy = 0.719
# Epoch 169/200, Loss = 18.750, Accuracy = 0.812
# Epoch 170/200, Loss = 21.875, Accuracy = 0.781
# Epoch 171/200, Loss = 18.750, Accuracy = 0.812
# Epoch 172/200, Loss = 28.125, Accuracy = 0.719
# Epoch 173/200, Loss = 31.250, Accuracy = 0.688
# Epoch 174/200, Loss = 25.000, Accuracy = 0.750
# Epoch 175/200, Loss = 28.125, Accuracy = 0.719
# Epoch 176/200, Loss = 34.375, Accuracy = 0.656
# Epoch 177/200, Loss = 40.625, Accuracy = 0.594
# Epoch 178/200, Loss = 28.125, Accuracy = 0.719
# Epoch 179/200, Loss = 25.000, Accuracy = 0.750
# Epoch 180/200, Loss = 25.000, Accuracy = 0.750
# Epoch 181/200, Loss = 31.250, Accuracy = 0.688
# Epoch 182/200, Loss = 37.500, Accuracy = 0.625
# Epoch 183/200, Loss = 21.875, Accuracy = 0.781
# Epoch 184/200, Loss = 31.250, Accuracy = 0.688
# Epoch 185/200, Loss = 25.000, Accuracy = 0.750
# Epoch 186/200, Loss = 25.000, Accuracy = 0.750
# Epoch 187/200, Loss = 21.875, Accuracy = 0.781
# Epoch 188/200, Loss = 28.125, Accuracy = 0.719
# Epoch 189/200, Loss = 21.875, Accuracy = 0.781
# Epoch 190/200, Loss = 34.375, Accuracy = 0.656
# Epoch 191/200, Loss = 34.375, Accuracy = 0.656
# Epoch 192/200, Loss = 28.125, Accuracy = 0.719
# Epoch 193/200, Loss = 28.125, Accuracy = 0.719
# Epoch 194/200, Loss = 18.750, Accuracy = 0.812
# Epoch 195/200, Loss = 31.250, Accuracy = 0.688
# Epoch 196/200, Loss = 25.000, Accuracy = 0.750
# Epoch 197/200, Loss = 31.250, Accuracy = 0.688
# Epoch 198/200, Loss = 28.125, Accuracy = 0.719
# Epoch 199/200, Loss = 34.375, Accuracy = 0.656
# Epoch 200/200, Loss = 21.875, Accuracy = 0.781
